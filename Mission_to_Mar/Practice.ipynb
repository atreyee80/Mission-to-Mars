# %%
pip freeze
# Out:
# appnope==0.1.2
# argon2-cffi==20.1.0
# async-generator==1.10
# attrs==20.3.0
# backcall==0.2.0
# bleach==3.3.0
# certifi==2020.12.5
# cffi==1.14.5
# chardet==4.0.0
# citipy==0.0.5
# click==7.1.2
# cycler==0.10.0
# decorator==4.4.2
# defusedxml==0.7.1
# entrypoints==0.3
# Flask==1.1.2
# Flask-SQLAlchemy==2.5.1
# geojson==2.5.0
# gmaps==0.9.0
# greenlet==1.0.0
# idna==2.10
# ipykernel==5.5.0
# ipython==7.22.0
# ipython-genutils==0.2.0
# ipywidgets==7.6.3
# itsdangerous==1.1.0
# jedi==0.18.0
# Jinja2==2.11.3
# jsonschema==3.2.0
# jupyter-client==6.1.12
# jupyter-core==4.7.1
# jupyterlab-pygments==0.1.2
# jupyterlab-widgets==1.0.0
# kdtree==0.16
# kiwisolver==1.3.1
# MarkupSafe==1.1.1
# matplotlib==3.4.0
# mistune==0.8.4
# nbclient==0.5.3
# nbconvert==6.0.7
# nbformat==5.1.3
# nest-asyncio==1.5.1
# notebook==6.3.0
# numpy==1.20.2
# packaging==20.9
# pandas==1.2.3
# pandocfilters==1.4.3
# parso==0.8.1
# pexpect==4.8.0
# pickleshare==0.7.5
# Pillow==8.1.2
# prometheus-client==0.10.1
# prompt-toolkit==3.0.18
# ptyprocess==0.7.0
# pycparser==2.20
# Pygments==2.8.1
# pyparsing==2.4.7
# pyrsistent==0.17.3
# python-dateutil==2.8.1
# pytz==2021.1
# pyzmq==22.0.3
# requests==2.25.1
# selenium==3.141.0
# Send2Trash==1.5.0
# six==1.15.0
# splinter==0.14.0
# SQLAlchemy==1.4.13
# terminado==0.9.4
# testpath==0.4.4
# tornado==6.1
# traitlets==5.0.5
# urllib3==1.26.4
# wcwidth==0.2.5
# webencodings==0.5.1
# Werkzeug==1.0.1
# widgetsnbextension==3.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install webdriver_manager
# Out:
# Collecting webdriver_manager
#   Using cached webdriver_manager-3.4.1-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: requests in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from webdriver_manager) (2.25.1)
# Collecting configparser
#   Using cached configparser-5.0.2-py3-none-any.whl (19 kB)
# Collecting crayons
#   Using cached crayons-0.4.0-py2.py3-none-any.whl (4.6 kB)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from requests->webdriver_manager) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from requests->webdriver_manager) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from requests->webdriver_manager) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from requests->webdriver_manager) (2020.12.5)
# Installing collected packages: colorama, crayons, configparser, webdriver-manager
# Successfully installed colorama-0.4.4 configparser-5.0.2 crayons-0.4.0 webdriver-manager-3.4.1
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the '/Users/saha/Desktop/Resources1/env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bs4
# Out:
# Collecting bs4
#   Using cached bs4-0.0.1-py3-none-any.whl
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 3.5 MB/s eta 0:00:01
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.2.1-py3-none-any.whl (33 kB)
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.9.3 bs4-0.0.1 soupsieve-2.2.1
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the '/Users/saha/Desktop/Resources1/env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
#Import Dependencies
from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager

# %%
#set the executable path and initialize a browser:
# Set up Splinter/an instance of splinter browser
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [/Users/saha/.wdm/drivers/chromedriver/mac64/90.0.4430.24/chromedriver] found in cache

# %%
#10.3.2Scrape the Title
# Visit the Quotes to Scrape site
url = 'http://quotes.toscrape.com/'
browser.visit(url)

# %%
# Parse the HTML
html = browser.html
html_soup = soup(html, 'html.parser')

# %%
# Scrape the Title
title = html_soup.find('h2').text
title
# Out:
# 'Top Ten tags'

# %%
# Scrape the top ten tags
tag_box = html_soup.find('div', class_='tags-box')
# tag_box
tags = tag_box.find_all('a', class_='tag')

for tag in tags:
    word = tag.text
    print(word)
# Out:
# love
# inspirational
# life
# humor
# books
# reading
# friendship
# friends
# truth
# simile

# %%
url = 'http://quotes.toscrape.com/'
browser.visit(url)

# %%
for x in range(1, 6):
   html = browser.html
   quote_soup = soup (html, 'html.parser')
   quotes = quote_soup.find_all('span', class_='text')
   for quote in quotes:
      print('page:', x, '----------')
      print(quote.text)
   browser.links.find_by_partial_text('Next')
# Out:
# page: 1 ----------
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# page: 1 ----------
# “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# page: 1 ----------
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# page: 1 ----------
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# page: 1 ----------
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# page: 1 ----------
# “Try not to become a man of success. Rather become a man of value.”
# page: 1 ----------
# “It is better to be hated for what you are than to be loved for what you are not.”
# page: 1 ----------
# “I have not failed. I've just found 10,000 ways that won't work.”
# page: 1 ----------
# “A woman is like a tea bag; you never know how strong it is until it's in hot water.”
# page: 1 ----------
# “A day without sunshine is like, you know, night.”
# page: 2 ----------
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# page: 2 ----------
# “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# page: 2 ----------
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# page: 2 ----------
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# page: 2 ----------
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# page: 2 ----------
# “Try not to become a man of success. Rather become a man of value.”
# page: 2 ----------
# “It is better to be hated for what you are than to be loved for what you are not.”
# page: 2 ----------
# “I have not failed. I've just found 10,000 ways that won't work.”
# page: 2 ----------
# “A woman is like a tea bag; you never know how strong it is until it's in hot water.”
# page: 2 ----------
# “A day without sunshine is like, you know, night.”
# page: 3 ----------
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# page: 3 ----------
# “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# page: 3 ----------
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# page: 3 ----------
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# page: 3 ----------
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# page: 3 ----------
# “Try not to become a man of success. Rather become a man of value.”
# page: 3 ----------
# “It is better to be hated for what you are than to be loved for what you are not.”
# page: 3 ----------
# “I have not failed. I've just found 10,000 ways that won't work.”
# page: 3 ----------
# “A woman is like a tea bag; you never know how strong it is until it's in hot water.”
# page: 3 ----------
# “A day without sunshine is like, you know, night.”
# page: 4 ----------
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# page: 4 ----------
# “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# page: 4 ----------
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# page: 4 ----------
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# page: 4 ----------
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# page: 4 ----------
# “Try not to become a man of success. Rather become a man of value.”
# page: 4 ----------
# “It is better to be hated for what you are than to be loved for what you are not.”
# page: 4 ----------
# “I have not failed. I've just found 10,000 ways that won't work.”
# page: 4 ----------
# “A woman is like a tea bag; you never know how strong it is until it's in hot water.”
# page: 4 ----------
# “A day without sunshine is like, you know, night.”
# page: 5 ----------
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# page: 5 ----------
# “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# page: 5 ----------
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# page: 5 ----------
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# page: 5 ----------
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# page: 5 ----------
# “Try not to become a man of success. Rather become a man of value.”
# page: 5 ----------
# “It is better to be hated for what you are than to be loved for what you are not.”
# page: 5 ----------
# “I have not failed. I've just found 10,000 ways that won't work.”
# page: 5 ----------
# “A woman is like a tea bag; you never know how strong it is until it's in hot water.”
# page: 5 ----------
# “A day without sunshine is like, you know, night.”

# %%
for x in range(1, 6):
   html = browser.html
   quote_soup = soup (html, 'html.parser')
   quotes = quote_soup.find_all('div', class_='quote')
   for quote in quotes:
      print('page:', x, '----------')
      print(quote.text)
   browser.links.find_by_partial_text('Next')
# Out:
# page: 1 ----------
#
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# by Albert Einstein
# (about)
#
#
#             Tags:
#
# change
# deep-thoughts
# thinking
# world
#
#
# page: 1 ----------
#
# “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# by J.K. Rowling
# (about)
#
#
#             Tags:
#
# abilities
# choices
#
#
# page: 1 ----------
#
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# by Albert Einstein
# (about)
#
#
#             Tags:
#
# inspirational
# life
# live
# miracle
# miracles
#
#
# page: 1 ----------
#
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# by Jane Austen
# (about)
#
#
#             Tags:
#
# aliteracy
# books
# classic
# humor
#
#
# page: 1 ----------
#
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# by Marilyn Monroe
# (about)
#
#
#             Tags:
#
# be-yourself
# inspirational
#
#
# page: 1 ----------
#
# “Try not to become a man of success. Rather become a man of value.”
# by Albert Einstein
# (about)
#
#
#             Tags:
#
# adulthood
# success
# value
#
#
# page: 1 ----------
#
# “It is better to be hated for what you are than to be loved for what you are not.”
# by André Gide
# (about)
#
#
#             Tags:
#
# life
# love
#
#
# page: 1 ----------
#
# “I have not failed. I've just found 10,000 ways that won't work.”
# by Thomas A. Edison
# (about)
#
#
#             Tags:
#
# edison
# failure
# inspirational
# paraphrased
#
#
# page: 1 ----------
#
# “A woman is like a tea bag; you never know how strong it is until it's in hot water.”
# by Eleanor Roosevelt
# (about)
#
#
#             Tags:
#
# misattributed-eleanor-roosevelt
#
#
# page: 1 ----------
#
# “A day without sunshine is like, you know, night.”
# by Steve Martin
# (about)
#
#
#             Tags:
#
# humor
# obvious
# simile
#
#
# page: 2 ----------
#
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# by Albert Einstein
# (about)
#
#
#             Tags:
#
# change
# deep-thoughts
# thinking
# world
#
#
# page: 2 ----------
#
# “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# by J.K. Rowling
# (about)
#
#
#             Tags:
#
# abilities
# choices
#
#
# page: 2 ----------
#
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# by Albert Einstein
# (about)
#
#
#             Tags:
#
# inspirational
# life
# live
# miracle
# miracles
#
#
# page: 2 ----------
#
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# by Jane Austen
# (about)
#
#
#             Tags:
#
# aliteracy
# books
# classic
# humor
#
#
# page: 2 ----------
#
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# by Marilyn Monroe
# (about)
#
#
#             Tags:
#
# be-yourself
# inspirational
#
#
# page: 2 ----------
#
# “Try not to become a man of success. Rather become a man of value.”
# by Albert Einstein
# (about)
#
#
#             Tags:
#
# adulthood
# success
# value
#
#
# page: 2 ----------
#
# “It is better to be hated for what you are than to be loved for what you are not.”
# by André Gide
# (about)
#
#
#             Tags:
#
# life
# love
#
#
# page: 2 ----------
#
# “I have not failed. I've just found 10,000 ways that won't work.”
# by Thomas A. Edison
# (about)
#
#
#             Tags:
#
# edison
# failure
# inspirational
# paraphrased
#
#
# page: 2 ----------
#
# “A woman is like a tea bag; you never know how strong it is until it's in hot water.”
# by Eleanor Roosevelt
# (about)
#
#
#             Tags:
#
# misattributed-eleanor-roosevelt
#
#
# page: 2 ----------
#
# “A day without sunshine is like, you know, night.”
# by Steve Martin
# (about)
#
#
#             Tags:
#
# humor
# obvious
# simile
#
#
# page: 3 ----------
#
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# by Albert Einstein
# (about)
#
#
#             Tags:
#
# change
# deep-thoughts
# thinking
# world
#
#
# page: 3 ----------
#
# “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# by J.K. Rowling
# (about)
#
#
#             Tags:
#
# abilities
# choices
#
#
# page: 3 ----------
#
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# by Albert Einstein
# (about)
#
#
#             Tags:
#
# inspirational
# life
# live
# miracle
# miracles
#
#
# page: 3 ----------
#
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# by Jane Austen
# (about)
#
#
#             Tags:
#
# aliteracy
# books
# classic
# humor
#
#
# page: 3 ----------
#
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# by Marilyn Monroe
# (about)
#
#
#             Tags:
#
# be-yourself
# inspirational
#
#
# page: 3 ----------
#
# “Try not to become a man of success. Rather become a man of value.”
# by Albert Einstein
# (about)
#
#
#             Tags:
#
# adulthood
# success
# value
#
#
# page: 3 ----------
#
# “It is better to be hated for what you are than to be loved for what you are not.”
# by André Gide
# (about)
#
#
#             Tags:
#
# life
# love
#
#
# page: 3 ----------
#
# “I have not failed. I've just found 10,000 ways that won't work.”
# by Thomas A. Edison
# (about)
#
#
#             Tags:
#
# edison
# failure
# inspirational
# paraphrased
#
#
# page: 3 ----------
#
# “A woman is like a tea bag; you never know how strong it is until it's in hot water.”
# by Eleanor Roosevelt
# (about)
#
#
#             Tags:
#
# misattributed-eleanor-roosevelt
#
#
# page: 3 ----------
#
# “A day without sunshine is like, you know, night.”
# by Steve Martin
# (about)
#
#
#             Tags:
#
# humor
# obvious
# simile
#
#
# page: 4 ----------
#
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# by Albert Einstein
# (about)
#
#
#             Tags:
#
# change
# deep-thoughts
# thinking
# world
#
#
# page: 4 ----------
#
# “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# by J.K. Rowling
# (about)
#
#
#             Tags:
#
# abilities
# choices
#
#
# page: 4 ----------
#
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# by Albert Einstein
# (about)
#
#
#             Tags:
#
# inspirational
# life
# live
# miracle
# miracles
#
#
# page: 4 ----------
#
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# by Jane Austen
# (about)
#
#
#             Tags:
#
# aliteracy
# books
# classic
# humor
#
#
# page: 4 ----------
#
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# by Marilyn Monroe
# (about)
#
#
#             Tags:
#
# be-yourself
# inspirational
#
#
# page: 4 ----------
#
# “Try not to become a man of success. Rather become a man of value.”
# by Albert Einstein
# (about)
#
#
#             Tags:
#
# adulthood
# success
# value
#
#
# page: 4 ----------
#
# “It is better to be hated for what you are than to be loved for what you are not.”
# by André Gide
# (about)
#
#
#             Tags:
#
# life
# love
#
#
# page: 4 ----------
#
# “I have not failed. I've just found 10,000 ways that won't work.”
# by Thomas A. Edison
# (about)
#
#
#             Tags:
#
# edison
# failure
# inspirational
# paraphrased
#
#
# page: 4 ----------
#
# “A woman is like a tea bag; you never know how strong it is until it's in hot water.”
# by Eleanor Roosevelt
# (about)
#
#
#             Tags:
#
# misattributed-eleanor-roosevelt
#
#
# page: 4 ----------
#
# “A day without sunshine is like, you know, night.”
# by Steve Martin
# (about)
#
#
#             Tags:
#
# humor
# obvious
# simile
#
#
# page: 5 ----------
#
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# by Albert Einstein
# (about)
#
#
#             Tags:
#
# change
# deep-thoughts
# thinking
# world
#
#
# page: 5 ----------
#
# “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# by J.K. Rowling
# (about)
#
#
#             Tags:
#
# abilities
# choices
#
#
# page: 5 ----------
#
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# by Albert Einstein
# (about)
#
#
#             Tags:
#
# inspirational
# life
# live
# miracle
# miracles
#
#
# page: 5 ----------
#
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# by Jane Austen
# (about)
#
#
#             Tags:
#
# aliteracy
# books
# classic
# humor
#
#
# page: 5 ----------
#
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# by Marilyn Monroe
# (about)
#
#
#             Tags:
#
# be-yourself
# inspirational
#
#
# page: 5 ----------
#
# “Try not to become a man of success. Rather become a man of value.”
# by Albert Einstein
# (about)
#
#
#             Tags:
#
# adulthood
# success
# value
#
#
# page: 5 ----------
#
# “It is better to be hated for what you are than to be loved for what you are not.”
# by André Gide
# (about)
#
#
#             Tags:
#
# life
# love
#
#
# page: 5 ----------
#
# “I have not failed. I've just found 10,000 ways that won't work.”
# by Thomas A. Edison
# (about)
#
#
#             Tags:
#
# edison
# failure
# inspirational
# paraphrased
#
#
# page: 5 ----------
#
# “A woman is like a tea bag; you never know how strong it is until it's in hot water.”
# by Eleanor Roosevelt
# (about)
#
#
#             Tags:
#
# misattributed-eleanor-roosevelt
#
#
# page: 5 ----------
#
# “A day without sunshine is like, you know, night.”
# by Steve Martin
# (about)
#
#
#             Tags:
#
# humor
# obvious
# simile

# %%
#10.3.3Scrape Mars Data: The News
